# %% [markdown]
# Human Resources Data analysis - Exploratory Data Analysis (EDA), Data Science and ML

# %% [markdown]
# Part A: Basic EDA (Exploratory Data Analysis)

# %%
# Load the libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
hr = pd.read_csv(r"Human Recources Data.csv")
hr.head(5)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# The dataset is loaded and the first 5 observations displayed

# %%
# Check the shape of the loaded dataset
hr.shape
# Out:
# (311, 36)

# %% [markdown]
# The dataset has 311 observations (rows) and 36 columns

# %%
# Display each column with its corresponding data type
hr.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %% [markdown]
# Each column is displayed with its corresponding data type, it shows that most of the variables (columns) have 'object' data types.

# %%
# Find the number of unique value in each column
unique_counts = hr.nunique()
print(unique_counts)
# Out:
# Employee_Name                 311
# EmpID                         311
# MarriedID                       2
# MaritalStatusID                 5
# GenderID                        2
# EmpStatusID                     5
# DeptID                          6
# PerfScoreID                     4
# FromDiversityJobFairID          2
# Salary                        308
# Termd                           2
# PositionID                     30
# Position                       32
# State                          28
# Zip                           158
# DOB                           307
# Sex                             2
# MaritalDesc                     5
# CitizenDesc                     3
# HispanicLatino                  4
# RaceDesc                        6
# DateofHire                    101
# DateofTermination              96
# TermReason                     18
# EmploymentStatus                3
# Department                      6
# ManagerName                    21
# ...

# %% [markdown]
# The results show that the column 'salary' had the highest number of unique values of 308 followed by 'DOB' which had 307 unique values

# %%
# Identify missing values in the dataset and list columns with nulls.
hr.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %% [markdown]
# The column 'DateofTermination' had 207 missing values, the only column with missing values in the dataset

# %%
# Describe the numerical columns with theire mean, median and standard deviation
hr.describe().T
# Out:
#                         count                           mean  \
# EmpID                   311.0                        10156.0
# MarriedID               311.0                       0.398714
# MaritalStatusID         311.0                       0.810289
# GenderID                311.0                       0.434084
# EmpStatusID             311.0                       2.392283
# DeptID                  311.0                       4.610932
# PerfScoreID             311.0                       2.977492
# FromDiversityJobFairID  311.0                       0.093248
# Salary                  311.0                   69020.684887
# Termd                   311.0                       0.334405
# PositionID              311.0                      16.845659
# Zip                     311.0                    6555.482315
# DOB                       311  1979-02-06 09:48:02.315112544
# ManagerID               303.0                      14.570957
# ...

# %% [markdown]
# Just to describe a few, the column 'salary' had a mean salary of 69020.684887, the median salary was 62810.000000 while the standard deviation was 25156.636930. These statistics show that the salary column is skewed due to the significant difference of the mean and median salary values.

# %%
# Finding the distribution of salary
plt.figure(figsize=(12,8))
sns.histplot(hr['Salary'], kde=True, color='skyblue')
plt.title('The distribution of Salary')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4428\4290286741.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# The salary column is skewed to the left, with most employees having a salary range between 50,000 and 100,000.

# %%
# What is the average age of employees at the company?
from datetime import datetime
hr['DOB'] = pd.to_datetime(hr['DOB'])
# today's date
today = pd.to_datetime('today')
hr['Age'] =(today.year - hr['DOB'].dt.year)
average_age = hr['Age'].mean()
print(average_age)
# Out:
# 46.40836012861736

# %%
# Which department has the most employees
employee_counts = hr['Department'].value_counts()
print(employee_counts)
# Out:
# Department
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: count, dtype: int64

# %%
# Plot the countplot
plt.figure(figsize=(12,8))
employee_counts.plot(kind='bar', x='Department')
plt.title('Count plot of Employees in Each department')
plt.xlabel('Department')
plt.ylabel('No. of Employees')
plt.show()

# %% [markdown]
# From the figure above, the production department had the highest number of employees followed by the IT/IS department and so on.

# %% [markdown]
# Part B: Business Analysis

# %%
# Average salary per department
average_salary = hr.groupby('Department')['Salary'].mean()
print(average_salary)
# Out:
# Department
# Admin Offices            71791.888889
# Executive Office        250000.000000
# IT/IS                    97064.640000
# Production               59953.545455
# Sales                    69061.258065
# Software Engineering     94989.454545
# Name: Salary, dtype: float64

# %% [markdown]
# The Executive office department have the highest average salary of 250,000. This is followed by the IT/IS department which had an average salary of approximately 97,000.

# %%
# The distribution of employement status
status_counts = hr['EmploymentStatus'].value_counts()
print(status_counts)
plt.figure(figsize=(12,8))
plt.pie(status_counts, labels=status_counts.index,
        startangle=90, autopct='%1.1f%%', colors=plt.cm.Pastel1.colors)
plt.title('Proportions of Employment status')
plt.show()
# Out:
# EmploymentStatus
# Active                    207
# Voluntarily Terminated     88
# Terminated for Cause       16
# Name: count, dtype: int64

# %% [markdown]
# The employment status of most employees is active (66.6%) with very few employees (5.1%) having terminated their employment with a cause.

# %%
# Compare the salary levels of male and female employees using a boxplot
plt.figure(figsize=(12,8))
sns.boxplot(x=hr['Sex'], y=hr['Salary'], palette='viridis')
plt.title('Comparison of Salary levels of Male and Female employees')
plt.xlabel('Sex of Employee')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4428\2287989488.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=hr['Sex'], y=hr['Salary'], palette='viridis')

# %%
# Recruitment source that brings in the most employees
recruiment_counts = hr['RecruitmentSource'].value_counts()
print(recruiment_counts)
# Out:
# RecruitmentSource
# Indeed                     87
# LinkedIn                   76
# Google Search              49
# Employee Referral          31
# Diversity Job Fair         29
# CareerBuilder              23
# Website                    13
# Other                       2
# On-line Web application     1
# Name: count, dtype: int64

# %% [markdown]
# 'Indeed' recruitment source brings in most employees (87) compared to the rest of the sources. This is followed closely by LinkedIn which brings in 76 employees.

# %%
# Percentage of employees who attended a Diversity job fair
perc_attended = (hr['FromDiversityJobFairID'].value_counts(normalize=True))*100
print(perc_attended)
# Out:
# FromDiversityJobFairID
# 0    90.675241
# 1     9.324759
# Name: proportion, dtype: float64

# %% [markdown]
# Approximately 91% of employees represents the '0' state while approx 9% represents the '1'.

# %%
# Compare engagement survey scores across different departments.
plt.figure(figsize=(12,8))
sns.barplot(x=hr['Department'], y=hr['EngagementSurvey'], palette='viridis')
plt.title('Comparison of Engagement Survey scores across Departments')
plt.xlabel('Department')
plt.ylabel('Engagement Scores')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4428\3135199366.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=hr['Department'], y=hr['EngagementSurvey'], palette='viridis')

# %% [markdown]
# The Executive office department had the highest engagement scores

# %%
# Race with the highest average salary
race_salary = hr.groupby('RaceDesc')['Salary'].mean()
print(race_salary)
# Out:
# RaceDesc
# American Indian or Alaska Native    65806.000000
# Asian                               68521.206897
# Black or African American           74431.025000
# Hispanic                            83667.000000
# Two or more races                   59998.181818
# White                               67287.545455
# Name: Salary, dtype: float64

# %% [markdown]
# The Hispanic race had the highest average salary (83667.000000) followed by the Blacks who had an average salary of 74431.025000 and so on.

# %%
# What is the relationship between number of projects (SpecialProjectsCount) and salary?
plt.figure(figsize=(12,8))
sns.scatterplot(x=hr['SpecialProjectsCount'], y=hr['Salary'])
plt.title('Relationship between Employee Special Project count and Salary')
plt.xlabel('Special Project Count')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# There is no clear relationship between the two variables

# %%
# Do married employees earn more on average than single employees?
marriage_atatus_count = hr.groupby('MarriedID')['Salary'].mean()
print(marriage_atatus_count)
# Out:
# MarriedID
# 0    68485.540107
# 1    69827.717742
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(12,8))
marriage_atatus_count.plot(kind='bar', x='MarriedID')
plt.title('Comparison of average earnings between Married Employees and Single Employees')
plt.xlabel('Married Status')
plt.ylabel('Average Salary')
plt.show()

# %% [markdown]
# The Married employees earn slightly higher than the single employees

# %%
# Manager with the largest team
manager_count = hr['ManagerID'].value_counts()
print(manager_count)
# Out:
# ManagerID
# 20.0    22
# 16.0    22
# 12.0    22
# 18.0    22
# 14.0    21
# 11.0    21
# 22.0    21
# 19.0    21
# 2.0     19
# 4.0     17
# 7.0     14
# 17.0    14
# 39.0    13
# 21.0    13
# 10.0     9
# 13.0     8
# 5.0      7
# 1.0      6
# 6.0      4
# 15.0     3
# 9.0      2
# 3.0      1
# 30.0     1
# Name: count, dtype: int64

# %% [markdown]
# PART C: VISUALIZATION

# %%
# Plot the salary distribution using histograms
plt.figure(figsize=(12,8))
sns.histplot(x=hr['Salary'], kde=True, color='red')
plt.title('The distribution of Salary')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The salary data is left skewed with most values ranging between 50000 and 100000

# %%
# show the count of employees by department
employee_counts = hr['Department'].value_counts()
plt.figure(figsize=(12,8))
employee_counts.plot(kind='bar', x='Department')
plt.title('The Countplot of Employees by Department')
plt.xlabel('Department')
plt.ylabel('Count of employees')
plt.show()

# %% [markdown]
# The Production department has the highest number of employees, approximately 225 employees

# %%
# Compare average satisfaction score by department.
plt.figure(figsize=(12,8))
sns.barplot(x=hr['Department'], y=hr['EmpSatisfaction'], palette='viridis')
plt.title('Barplot of Employee satisfaction by Department')
plt.xlabel('Department')
plt.ylabel('Employee Satisfaction score')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4428\1179703524.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=hr['Department'], y=hr['EmpSatisfaction'], palette='viridis')

# %%
# Visualize employee terminations over time.
from datetime import datetime
hr['DateofTermination'] = pd.to_datetime(hr['DateofTermination'])

# %%
avg_terminationd = hr.groupby('DateofTermination')['Termd'].mean().reset_index()
plt.figure(figsize=(12,8))
sns.lineplot(x='DateofTermination', y = 'Termd', data=avg_terminationd)
plt.title('Terminations over time')
plt.xlabel('Date of Termination')
plt.ylabel('Termd')
plt.show()

# %%
# Plot average salary by gender using a boxplot.
plt.figure(figsize=(12,8))
sns.boxplot(x=hr['GenderID'], y=hr['Salary'], palette='Set2')
plt.title('Boxplot of average salary by gender')
plt.xlabel('Gender (0 - Female, 1 - Male)')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4428\3262259933.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=hr['GenderID'], y=hr['Salary'], palette='Set2')

# %% [markdown]
# The males have a slightly higher average salary compared to their female counterparts. Again, the males have a higher Interqurtile range compared to the females.

# %%
# Visualize performance scores vs salary.
plt.figure(figsize=(12,8))
sns.stripplot(x=hr['PerformanceScore'], y=hr['Salary'])
plt.title('Stripplot of Performance Scores versus Salary')
plt.xlabel('Performance Scores')
plt.ylabel('Salary')
plt.show()

# %%
numeric_columns = ['Salary', 'EngagementSurvey', 'EmpSatisfaction',
       'SpecialProjectsCount', 'DaysLateLast30',
       'Absences', 'Age']
df = hr[numeric_columns]
correlation_matrix = df.corr()

# %%
# plot the heatmap
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', cbar=True)
plt.title('A correlation matrix of Human resource numerical features')
plt.show()

# %%
# Plot engagement survey score vs satisfaction score.
# Scatterplot
plt.figure(figsize=(12,8))
sns.scatterplot(x=hr['EmpSatisfaction'], y=hr['EngagementSurvey'])
plt.title('Scatter plot of Engagement survey score and Satisfaction score')
plt.xlabel('Employee satisfaction score')
plt.ylabel('Engagement survey score')
plt.show()

# %% [markdown]
# No identifiable pattern, means no relationship between the 2 variables

# %%
# Show a stacked bar chart of employee status across departments.

# create a crosstab of department vs. employment status- this aggregates the counts of employment status per department
dept_status = pd.crosstab(hr['EmploymentStatus'], hr['Department'])
dept_status.plot(kind = 'bar', stacked = True, figsize=(12,8))
plt.title('Stacked bar chart of Employement status across Departments')
plt.xlabel('Employment status')
plt.ylabel('Count')
plt.show()

# %%
# Plot absenteeism (Absences) distribution among employees.
plt.figure(figsize=(12,8))
sns.histplot(x=hr['Absences'],bins=20, kde=True, color='red')
plt.title('Distribution of Absenteesm among employees')
plt.xlabel('Absences')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Part D: Principal Component Analysis - PCA (Dimensionality Reduction)

# %%
# Subset numeric data only
numeric_columns = ['Salary', 'EngagementSurvey', 'EmpSatisfaction',
       'SpecialProjectsCount', 'DaysLateLast30',
       'Absences', 'Age']
df = hr[numeric_columns].head()
# Out:
#    Salary  EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 0   62506              4.60                5                     0
# 1  104437              4.96                3                     6
# 2   64955              3.02                3                     0
# 3   64991              4.84                5                     0
# 4   50825              5.00                4                     0
#
#    DaysLateLast30  Absences  Age
# 0               0         1   42
# 1               0        17   50
# 2               0         3   37
# 3               0        15   37
# 4               0         2   36

# %%
# Scaling the data
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA

# %%
# Standardize numerical features before applying PCA.
scaler = StandardScaler()
scaled = scaler.fit_transform(df)

# %%
# Apply PCA
pca = PCA(n_components=7)
pca_result = pca.fit_transform(scaled)
#Plot results
plt.scatter(pca_result[:, 0], pca_result[:, 1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Result")
plt.grid(True)
plt.show()

# %%
# Plot the explained variance ratio for the PCA components.
# Choosing the numbe of components (scree plot)
pca = PCA().fit(scaled)
plt.plot(range(1, len(pca.explained_variance_ratio_)+1),
    pca.explained_variance_ratio_.cumsum(), marker = 'o')
plt.xlabel('Number of components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.title('Explained variance vs. Number of components')
plt.show()

# %%
# separate features and labels
le = LabelEncoder()
hr['Department_encoded'] = le.fit_transform(hr['Department'])
X = hr[numeric_columns]
y = hr['Department_encoded']

# %%
# Standardize features before PCA
X_scaled = StandardScaler().fit_transform(X)
# Apply PCA to reduce to 2 dimensions
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
# Create a DataFrame with PCA results
pca_df = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2'])
pca_df['Department_encoded'] = y.values

# %%
# Plot the PCA results colored by department
plt.figure(figsize=(8,6))
for dept in pca_df['Department_encoded'].unique():
    subset = pca_df[pca_df['Department_encoded'] == dept]
    plt.scatter(subset['PC1'], subset['PC2'], label=dept, alpha=0.7)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Employees Colored by Department')
plt.legend()
plt.show()

# %%
X = hr[['EngagementSurvey', 'EmpSatisfaction', 'Absences']]

# Standardize the variables
X_scaled = StandardScaler().fit_transform(X)

# Apply PCA
pca = PCA()
pca.fit(X_scaled)

# Explained variance ratio
print("Explained variance ratio:", pca.explained_variance_ratio_)
print("Cumulative variance explained:", pca.explained_variance_ratio_.cumsum())

# Loadings (coefficients for each variable in components)
loadings = pd.DataFrame(pca.components_.T,
                        columns=[f'PC{i+1}' for i in range(len(pca.components_))],
                        index=X.columns)
print("\nLoadings:\n", loadings)
# Out:
# Explained variance ratio: [0.39958328 0.33535499 0.26506173]
# Cumulative variance explained: [0.39958328 0.73493827 1.        ]
#
# Loadings:
#                         PC1       PC2       PC3
# EngagementSurvey  0.659712 -0.371955 -0.653016
# EmpSatisfaction   0.712038  0.031431  0.701437
# Absences          0.240378  0.927719 -0.285581

# %%
# Drop non-numeric or target columns
X = hr[numeric_columns]
y = hr['PerformanceScore']

# Standardize before PCA
X_scaled = StandardScaler().fit_transform(X)

# Apply PCA → reduce to 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Build PCA DataFrame
pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
pca_df['PerformanceScore'] = y.values

# Plot with seaborn
plt.figure(figsize=(8,6))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='PerformanceScore', palette='Set2', alpha=0.8, s=80)

plt.title('Employees in PCA-Reduced 2D Space by Performance Score')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Performance Score')
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# define features
X = hr[numeric_columns]
# Standardize features
X_scaled = StandardScaler().fit_transform(X)

# KMeans on original scaled data
kmeans_orig = KMeans(n_clusters=3, random_state=42, n_init=10)
labels_orig = kmeans_orig.fit_predict(X_scaled)
silhouette_orig = silhouette_score(X_scaled, labels_orig)

print(f"Silhouette Score (original data): {silhouette_orig:.3f}")

# PCA to 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# KMeans on PCA-reduced data
kmeans_pca = KMeans(n_clusters=3, random_state=42, n_init=10)
labels_pca = kmeans_pca.fit_predict(X_pca)
silhouette_pca = silhouette_score(X_pca, labels_pca)

print(f"Silhouette Score (after PCA): {silhouette_pca:.3f}")

# Visualize clustering results after PCA
pca_df = pd.DataFrame(X_pca, columns=['PC1','PC2'])
pca_df['Cluster'] = labels_pca

plt.figure(figsize=(8,6))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='Cluster', palette='Set2', s=80)
plt.title('KMeans Clusters After PCA')
plt.show()
# Out:
# Silhouette Score (original data): 0.316
# Silhouette Score (after PCA): 0.636

# %% [markdown]
# Clustering after PCA shows much better separation, with the silhouette score improving from 0.316 to 0.636. This means PCA effectively captured the underlying structure, making the clusters more distinct and well-formed.

# %%
X = hr[['Salary', 'Absences', 'EngagementSurvey']]

# Standardize features
X_scaled = StandardScaler().fit_transform(X)

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Create DataFrame of PCA results
pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])

# Get loadings (coefficients of variables on PCs)
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)

# Plot PCA points
plt.figure(figsize=(8,6))
plt.scatter(pca_df['PC1'], pca_df['PC2'], alpha=0.6)

# Plot loadings as arrows
for i, var in enumerate(['Salary','Absences','EngagementSurvey']):
    plt.arrow(0, 0, loadings[i,0]*2, loadings[i,1]*2, 
              color='red', alpha=0.7, head_width=0.05)
    plt.text(loadings[i,0]*2.2, loadings[i,1]*2.2, var, color='red', ha='center')

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA Biplot: Salary, Absences, EngagementSurvey')
plt.grid(True)
plt.axhline(0, color='gray', lw=1)
plt.axvline(0, color='gray', lw=1)
plt.show()

# %% [markdown]
# PCA is useful in HR analytics when you have many correlated variables and want to condense them into fewer, interpretable dimensions without losing much information. A common example is employee surveys: instead of analyzing 30–40 individual Likert-scale questions, PCA can reduce them into broader factors like job satisfaction, engagement, or workplace culture. This not only simplifies reporting but also reduces noise and multicollinearity in predictive models.
#
# It’s also appropriate for exploratory analysis when the goal is to identify hidden patterns, such as grouping related performance indicators, training outcomes, or well-being measures. However, PCA is most effective when variables are continuous, moderately correlated, and measured on similar scales—otherwise the reduction may not be meaningful.
#
# In HR contexts, PCA works best to summarize complex datasets (e.g., surveys, performance metrics, engagement indices) into a smaller set of interpretable dimensions that can then be used for clustering employees, predicting turnover, or tracking cultural shifts over time.
